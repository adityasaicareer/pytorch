# %%
import torch
from torch import nn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torchvision
from torchvision import datasets,transforms
from torchvision.transforms import ToTensor

# %%
train_data=datasets.FashionMNIST(root='data1',
                                 train=True,
                                 download=True,
                                 transform=ToTensor(),
                                 target_transform=None)
test_data=datasets.FashionMNIST(root='data1',
                                train=False,
                                download=True,
                                transform=ToTensor(),
                                target_transform=None)
# Out:
# ...
# 100%|██████████████████████████| 26421880/26421880 [00:25<00:00, 1041797.02it/s]
# Extracting data1/FashionMNIST/raw/train-images-idx3-ubyte.gz to data1/FashionMNIST/raw
#
# ...
# 100%|█████████████████████████████████| 29515/29515 [00:00<00:00, 149977.69it/s]
# Extracting data1/FashionMNIST/raw/train-labels-idx1-ubyte.gz to data1/FashionMNIST/raw
#
# ...
# 100%|█████████████████████████████| 4422102/4422102 [00:10<00:00, 409299.83it/s]
# Extracting data1/FashionMNIST/raw/t10k-images-idx3-ubyte.gz to data1/FashionMNIST/raw
#
# ...
# 100%|██████████████████████████████████| 5148/5148 [00:00<00:00, 2014204.94it/s]
# Extracting data1/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz to data1/FashionMNIST/raw

# %%
labels=train_data.classes

# %%
ind=train_data.class_to_idx

# %%
ind
# Out:
# {'T-shirt/top': 0,
#  'Trouser': 1,
#  'Pullover': 2,
#  'Dress': 3,
#  'Coat': 4,
#  'Sandal': 5,
#  'Shirt': 6,
#  'Sneaker': 7,
#  'Bag': 8,
#  'Ankle boot': 9}

# %%
ind.keys()
# Out:
# dict_keys(['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot'])

# %%
image,label=train_data[0]

# %%
image
# Out:
# tensor([[[0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0039, 0.0000, 0.0000, 0.0510,
# ...

# %%
plt.imshow(image.squeeze())
plt.axis(False)
# Out:
# (-0.5, 27.5, 27.5, -0.5)

# %%
fig=plt.figure(figsize=(4,4))
row=4
cols=4

for i in range(1,row*cols+1,1):
    fig.add_subplot(row,cols,i)
    rand=torch.randint(1,len(train_data),size=[1]).item()
    img,l=train_data[rand]
    plt.imshow(img.squeeze(),cmap=plt.cm.RdYlBu)
    plt.axis(False)
